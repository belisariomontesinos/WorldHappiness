# %% [markdown]
# # World Happiness Report EDA #
# By: Belisario Montesinos

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
h15 = pd.read_csv("~/JupyterProjects/WorldHappiness/Data/2015.csv") 
h16 = pd.read_csv("~/JupyterProjects/WorldHappiness/Data/2016.csv") 
h17 = pd.read_csv("~/JupyterProjects/WorldHappiness/Data/2017.csv") 
h18 = pd.read_csv("~/JupyterProjects/WorldHappiness/Data/2018.csv") 
h19 = pd.read_csv("~/JupyterProjects/WorldHappiness/Data/2019.csv")

# %%
h15.head()
#h19.info()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
h15['Year']='2015'
h16['Year']='2016'
h17['Year']='2017'
h18['Year']='2018'
h19['Year']='2019'
h19.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption  Year
# 0                      0.393  2019
# 1                      0.410  2019
# ...

# %%
y15 = h15.rename(columns={'Happiness Rank': 'Rank', 'Happiness Score': 'Score', 'Economy (GDP per Capita)' : 'GDP', 'Health (Life Expectancy)' : 'Health', 'Trust (Government Corruption)' : 'Trust'})
y16 = h16.rename(columns={'Happiness Rank': 'Rank', 'Happiness Score': 'Score', 'Economy (GDP per Capita)' : 'GDP', 'Health (Life Expectancy)' : 'Health', 'Trust (Government Corruption)' : 'Trust'})
y17 = h17.rename(columns={'Happiness.Rank': 'Rank', 'Happiness.Score': 'Score', 'Economy..GDP.per.Capita.' : 'GDP', 'Health..Life.Expectancy.' : 'Health', 'Trust..Government.Corruption.' : 'Trust'})
y18 = h18.rename(columns={'Overall rank': 'Rank', 'Country or region': 'Country', 'GDP per capita' : 'GDP', 'Healthy life expectancy' : 'Health', 'Perceptions of corruption' : 'Trust', 'Freedom to make life choices' : 'Freedom', 'Social support' : 'Family'})
y19 = h19.rename(columns={'Overall rank': 'Rank', 'Country or region': 'Country', 'GDP per capita' : 'GDP', 'Healthy life expectancy' : 'Health', 'Perceptions of corruption' : 'Trust', 'Freedom to make life choices' : 'Freedom', 'Social support' : 'Family'})

# %% [markdown]
# Modify df's to a uniform 10 Columns; Country, Year, Rank, Score, GDP, Family, Health, Trust, Freedom, Generosity.

# %%
#2017
h17.head()
y17 = h17.rename(columns={'Happiness.Rank': 'Rank', 'Happiness.Score': 'Score', 'Economy..GDP.per.Capita.' : 'GDP', 'Health..Life.Expectancy.' : 'Health', 'Trust..Government.Corruption.' : 'Trust'})
y17.head()
# Out:
#        Country  Rank  Score  Whisker.high  Whisker.low       GDP    Family  \
# 0       Norway     1  7.537      7.594445     7.479556  1.616463  1.533524
# 1      Denmark     2  7.522      7.581728     7.462272  1.482383  1.551122
# 2      Iceland     3  7.504      7.622030     7.385970  1.480633  1.610574
# 3  Switzerland     4  7.494      7.561772     7.426227  1.564980  1.516912
# 4      Finland     5  7.469      7.527542     7.410458  1.443572  1.540247
#
#      Health   Freedom  Generosity     Trust  Dystopia.Residual  Year
# 0  0.796667  0.635423    0.362012  0.315964           2.277027  2017
# 1  0.792566  0.626007    0.355280  0.400770           2.313707  2017
# 2  0.833552  0.627163    0.475540  0.153527           2.322715  2017
# 3  0.858131  0.620071    0.290549  0.367007           2.276716  2017
# 4  0.809158  0.617951    0.245483  0.382612           2.430182  2017

# %%
df = pd.concat([y15,y16,y17,y18,y19], ignore_index= True)
df.tail()
# Out:
#                       Country Region  Rank  Score  Standard Error    GDP  \
# 777                    Rwanda    NaN   152  3.334             NaN  0.359
# 778                  Tanzania    NaN   153  3.231             NaN  0.476
# 779               Afghanistan    NaN   154  3.203             NaN  0.350
# 780  Central African Republic    NaN   155  3.083             NaN  0.026
# 781               South Sudan    NaN   156  2.853             NaN  0.306
#
#      Family  Health  Freedom  Trust  Generosity  Dystopia Residual  Year  \
# 777   0.711   0.614    0.555  0.411       0.217                NaN  2019
# 778   0.885   0.499    0.417  0.147       0.276                NaN  2019
# 779   0.517   0.361    0.000  0.025       0.158                NaN  2019
# 780   0.000   0.105    0.225  0.035       0.235                NaN  2019
# 781   0.575   0.295    0.010  0.091       0.202                NaN  2019
#
#      Lower Confidence Interval  Upper Confidence Interval  Whisker.high  \
# ...

# %%
df = pd.concat([y15,y16,y17,y18,y19], ignore_index= True)
#df.info()
df.tail()
# Out:
#                       Country Region  Happiness Rank  Happiness Score  \
# 465                    Rwanda    NaN             NaN              NaN
# 466                     Syria    NaN             NaN              NaN
# 467                  Tanzania    NaN             NaN              NaN
# 468                   Burundi    NaN             NaN              NaN
# 469  Central African Republic    NaN             NaN              NaN
#
#      Standard Error  Economy (GDP per Capita)    Family  \
# 465             NaN                       NaN  0.945707
# 466             NaN                       NaN  0.396103
# 467             NaN                       NaN  1.041990
# 468             NaN                       NaN  0.629794
# 469             NaN                       NaN  0.000000
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  ...  \
# 465                       NaN  0.581844                            NaN  ...
# ...

# %%
multi = df.set_index(['Country', 'Year'])
multi.head()
# Out:
#                           Region  Rank  Score  Standard Error      GDP  \
# Country     Year
# Switzerland 2015  Western Europe     1  7.587         0.03411  1.39651
# Iceland     2015  Western Europe     2  7.561         0.04884  1.30232
# Denmark     2015  Western Europe     3  7.527         0.03328  1.32548
# Norway      2015  Western Europe     4  7.522         0.03880  1.45900
# Canada      2015   North America     5  7.427         0.03553  1.32629
#
#                    Family   Health  Freedom    Trust  Generosity  \
# Country     Year
# Switzerland 2015  1.34951  0.94143  0.66557  0.41978     0.29678
# Iceland     2015  1.40223  0.94784  0.62877  0.14145     0.43630
# Denmark     2015  1.36058  0.87464  0.64938  0.48357     0.34139
# Norway      2015  1.33095  0.88521  0.66973  0.36503     0.34699
# Canada      2015  1.32261  0.90563  0.63297  0.32957     0.45811
#
#                   Dystopia Residual  Lower Confidence Interval  \
# Country     Year
# ...

# %%
multi.sort_values(by=['Country', 'Year'])
# Out:
#                               Region  Rank  Score  Standard Error       GDP  \
# Country     Year
# Afghanistan 2015       Southern Asia   153  3.575         0.03084  0.319820
#             2016       Southern Asia   154  3.360             NaN  0.382270
#             2017                 NaN   141  3.794             NaN  0.401477
#             2018                 NaN   145  3.632             NaN  0.332000
#             2019                 NaN   154  3.203             NaN  0.350000
# ...                              ...   ...    ...             ...       ...
# Zimbabwe    2015  Sub-Saharan Africa   115  4.610         0.04290  0.271000
#             2016  Sub-Saharan Africa   131  4.193             NaN  0.350410
#             2017                 NaN   138  3.875             NaN  0.375847
#             2018                 NaN   144  3.692             NaN  0.357000
#             2019                 NaN   146  3.663             NaN  0.366000
#
# ...

# %%
happy = multi.drop(['Standard Error', 'Dystopia Residual', 'Lower Confidence Interval', 'Upper Confidence Interval', 'Whisker.high', 'Whisker.low', 'Dystopia.Residual'], axis=1)
happy.sort_values(by=['Country', 'Year'])
# Out:
#                               Region  Rank  Score       GDP    Family  \
# Country     Year
# Afghanistan 2015       Southern Asia   153  3.575  0.319820  0.302850
#             2016       Southern Asia   154  3.360  0.382270  0.110370
#             2017                 NaN   141  3.794  0.401477  0.581543
#             2018                 NaN   145  3.632  0.332000  0.537000
#             2019                 NaN   154  3.203  0.350000  0.517000
# ...                              ...   ...    ...       ...       ...
# Zimbabwe    2015  Sub-Saharan Africa   115  4.610  0.271000  1.032760
#             2016  Sub-Saharan Africa   131  4.193  0.350410  0.714780
#             2017                 NaN   138  3.875  0.375847  1.083096
#             2018                 NaN   144  3.692  0.357000  1.094000
#             2019                 NaN   146  3.663  0.366000  1.114000
#
#                     Health   Freedom     Trust  Generosity
# Country     Year
# ...

# %%
happy = happy.groupby(['Country']).ffill()
happy.sort_values(by=['Country', 'Year'])
happy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 782 entries, ('Switzerland', '2015') to ('South Sudan', '2019')
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Region      774 non-null    object
#  1   Rank        782 non-null    int64
#  2   Score       782 non-null    float64
#  3   GDP         782 non-null    float64
#  4   Family      782 non-null    float64
#  5   Health      782 non-null    float64
#  6   Freedom     782 non-null    float64
#  7   Trust       782 non-null    float64
#  8   Generosity  782 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 58.7+ KB

# %%
happy.isnull()
# Out:
#                                Region   Rank  Score    GDP  Family  Health  \
# Country                  Year
# Switzerland              2015   False  False  False  False   False   False
# Iceland                  2015   False  False  False  False   False   False
# Denmark                  2015   False  False  False  False   False   False
# Norway                   2015   False  False  False  False   False   False
# Canada                   2015   False  False  False  False   False   False
# ...                               ...    ...    ...    ...     ...     ...
# Rwanda                   2019   False  False  False  False   False   False
# Tanzania                 2019   False  False  False  False   False   False
# Afghanistan              2019   False  False  False  False   False   False
# Central African Republic 2019   False  False  False  False   False   False
# South Sudan              2019   False  False  False  False   False   False
#
# ...

# %%
happy = happy.dropna()
happy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 774 entries, ('Switzerland', '2015') to ('South Sudan', '2019')
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Region      774 non-null    object
#  1   Rank        774 non-null    int64
#  2   Score       774 non-null    float64
#  3   GDP         774 non-null    float64
#  4   Family      774 non-null    float64
#  5   Health      774 non-null    float64
#  6   Freedom     774 non-null    float64
#  7   Trust       774 non-null    float64
#  8   Generosity  774 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 58.2+ KB

# %%
gooddf = happy.sort_values(by=['Country', 'Year'])

# %%
happy['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 195
# Central and Eastern Europe         144
# Latin America and Caribbean        109
# Western Europe                     103
# Middle East and Northern Africa     96
# Southeastern Asia                   44
# Southern Asia                       35
# Eastern Asia                        28
# North America                       10
# Australia and New Zealand           10
# Name: Region, dtype: int64

# %%
happy.describe()
# Out:
#              Rank       Score         GDP      Family      Health     Freedom  \
# count  774.000000  774.000000  774.000000  774.000000  774.000000  774.000000
# mean    78.856589    5.375673    0.913601    1.076215    0.610695    0.410746
# std     45.304676    1.131273    0.407126    0.330124    0.248253    0.153441
# min      1.000000    2.693000    0.000000    0.000000    0.000000    0.000000
# 25%     40.000000    4.507250    0.603537    0.868088    0.440015    0.309103
# 50%     79.000000    5.312500    0.978120    1.122205    0.646960    0.431000
# 75%    118.000000    6.180000    1.233561    1.324528    0.807412    0.531165
# max    158.000000    7.769000    2.096000    1.644000    1.141000    0.724000
#
#             Trust  Generosity
# count  774.000000  774.000000
# mean     0.125814    0.218493
# std      0.106123    0.122766
# min      0.000000    0.000000
# 25%      0.055000    0.129822
# 50%      0.091033    0.202000
# 75%      0.155861    0.279705
# ...

# %%
happy.corr(method ='pearson')
# Out:
#                 Rank     Score       GDP    Family    Health   Freedom  \
# Rank        1.000000 -0.992097 -0.794946 -0.643584 -0.745814 -0.537916
# Score      -0.992097  1.000000  0.789875  0.647938  0.744628  0.551375
# GDP        -0.794946  0.789875  1.000000  0.584250  0.784175  0.340014
# Family     -0.643584  0.647938  0.584250  1.000000  0.572521  0.419843
# Health     -0.745814  0.744628  0.784175  0.572521  1.000000  0.341879
# Freedom    -0.537916  0.551375  0.340014  0.419843  0.341879  1.000000
# Trust      -0.379820  0.404804  0.313990  0.128123  0.251151  0.458976
# Generosity -0.118964  0.138748 -0.015696 -0.036925  0.009975  0.291760
#
#                Trust  Generosity
# Rank       -0.379820   -0.118964
# Score       0.404804    0.138748
# GDP         0.313990   -0.015696
# Family      0.128123   -0.036925
# Health      0.251151    0.009975
# Freedom     0.458976    0.291760
# Trust       1.000000    0.315730
# Generosity  0.315730    1.000000

# %%
scorecorr = happy.groupby(['Region']).corr(method ='pearson')['Score']
scorecorr = scorecorr.to_frame()
scorecorr.head()
# Out:
#                                      Score
# Region
# Australia and New Zealand Rank   -0.910378
#                           Score   1.000000
#                           GDP    -0.067446
#                           Family -0.335578
#                           Health -0.632106

# %%
gdpregion = scorecorr[scorecorr['Score'] == 'GDP']
# Out:
# Empty DataFrame
# Columns: [Score]
# Index: []

# %%
scorecorr.info
# Out:
# <bound method DataFrame.info of                                          Score
# Region
# Australia and New Zealand Rank       -0.910378
#                           Score       1.000000
#                           GDP        -0.067446
#                           Family     -0.335578
#                           Health     -0.632106
# ...                                        ...
# Western Europe            Family      0.516769
#                           Health      0.054105
#                           Freedom     0.777607
#                           Trust       0.823549
#                           Generosity  0.559289
#
# [80 rows x 1 columns]>

# %%
scorecorr.plot(kind='bar', stacked=True)

# %%
#happy.unstack(level=0).plot(kind='bar', subplots=True)
happy.corr(method ='pearson').plot(kind='bar', subplots=True)

# %%
happy.GDP.unstack(level=1).plot(subplots=True, figsize=(15, 60), layout=(10, 2));

# %%
f, a = plt.subplots(nrows=2, ncols=2, figsize=(9, 12), dpi= 80)

#happy.xs(happy['GDP']).plot(ax=a[0])
happy.xs(happy['Country']).plot(ax=a[1])
df.xs('Var3').plot(x=a[2])
df.xs('Var4').plot(kax=a[3])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-137-fdce4900567b> in <module>
#       2
# ...

# %%
gooddf.reset_index().pivot('Year','Country','GDP').plot(ax=a[0,0], title='Var1', grid=True)
plt.show()

# %%
gooddf.plot(ax=a[0,0], title='Var1', grid=True)
plt.show()

# %%
happy.pivot('Year','Country','GDP').unstack(level=1).plot(subplots=True, figsize=(15, 60), layout=(10, 2));
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-159-77e7745a27ec> in <module>
# ...

# %%
happy.to_csv(r"~/JupyterProjects/WorldHappiness/Data/happymaster.csv", index = True)
